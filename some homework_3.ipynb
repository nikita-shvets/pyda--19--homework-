# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = pd.read_csv('water.csv')
df.head(10)
df.plot(kind = 'scatter',
        x = 'hardness',
        y = 'mortality',
        title = 'Correlation between hardness of water and mortality',
        colormap = 'magma')
print(df[['hardness' , 'mortality']].corr(method = 'spearman'))
print(df[['hardness' , 'mortality']].corr(method = 'kendall'))
X = df[['hardness']]
y = df['mortality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
print('coef',model.coef_)
print('intercept',model.intercept_)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
#            hardness  mortality
# hardness   1.000000  -0.631665
# mortality -0.631665   1.000000
#            hardness  mortality
# hardness   1.000000  -0.453753
# mortality -0.453753   1.000000
# coef [-3.13167087]
# intercept 1668.9722977277095
# [1340.14685615 1637.65558901 1625.12890552 1531.17877935 1424.7019697
#  1606.33888028 1252.46007173 1434.09698232 1603.20720941 1650.18227249
#  1484.20371627 1415.30695708 1546.83713371 1625.12890552 1446.62366581
#  1546.83713371 1637.65558901 1621.99723465 1352.67353964]

# %%
model.score(X_test, y_test)
# Out:
# 0.5046490611017092

# %%
plt.plot(X_test.sort_values(by = 'hardness'), y_test - y_pred)

# %%
df_1 = df[df['location'] == 'South']
df_2 = df[df['location'] == 'North']
df_1.plot(kind = 'scatter',
        x = 'hardness',
        y = 'mortality',
        title = 'Correlation between hardness of water and mortality',
        colormap = 'magma')
print(df_1[['hardness' , 'mortality']].corr(method = 'spearman'))
print(df_1[['hardness' , 'mortality']].corr(method = 'kendall'))
X = df_1[['hardness']]
y = df_1['mortality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
print('coef',model_1.coef_)
print('intercept',model_1.intercept_)
y_pred = model_1.predict(X_test)
print(y_pred)
# Out:
#            hardness  mortality
# hardness   1.000000  -0.595723
# mortality -0.595723   1.000000
#            hardness  mortality
# hardness   1.000000  -0.440315
# mortality -0.440315   1.000000
# coef [-3.51342921]
# intercept 1640.2204603423374
# [1211.58209643 1622.65331428 1271.31039304 1211.58209643 1510.22357948
#  1566.43844688 1432.92813681 1622.65331428]

# %%
model_1.score(X_test, y_test)
# Out:
# -2.551922301235205

# %%
X_test_modify = X_test.sort_values(by = 'hardness', ascending = False)
ax = plt.plot(X_test_modify,y_test-y_pred, color = 'm').
plt.title('график остатков')
plt.show()

# %%
df_2.plot(kind = 'scatter',
        x = 'hardness',
        y = 'mortality',
        title = 'Correlation between hardness of water and mortality',
        colormap = 'magma')
print(df_2[['hardness' , 'mortality']].corr(method = 'spearman'))
print(df_2[['hardness' , 'mortality']].corr(method = 'kendall'))
X = df_2[['hardness']]
y = df_2['mortality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
model_2 = LinearRegression()
model_2.fit(X_train, y_train)
print('coef',model_2.coef_)
print('intercept',model_2.intercept_)
y_pred = model_2.predict(X_test)
print(y_pred)
# Out:
#            hardness  mortality
# hardness   1.000000  -0.404208
# mortality -0.404208   1.000000
#            hardness  mortality
# hardness   1.000000  -0.283058
# mortality -0.283058   1.000000
# coef [-1.97686226]
# intercept 1688.150229031281
# [1672.33533095 1670.35846869 1660.47415739 1676.28905547 1656.52043287
#  1547.79300857 1601.16828959 1672.33533095 1611.05260089 1658.49729513
#  1611.05260089]

# %%
model_2.score(X_test, y_test)
# Out:
# 0.018885304285745863

# %%
X_test_modify = X_test.sort_values(by = 'hardness', ascending = False)
ax = plt.plot(X_test_modify,y_test-y_pred, color = 'm')
plt.title('график остатков')
plt.show()

# %%
# вывод при разделении регионов зависимость становится нелинейной
# Out:
#     hardness
# 0        105
# 5         10
# 46        14
# 31        44
# 13        78
# 55        20
# 34       133
# 49        75
# 12        21
# 40         6
# 33        59
# 59        81
# 16        39
# 3         14
# 53        71
# 17        39
# 8         10
# 6         15
# 41       101

# %%
df.shape
# Out:
# (61, 5)
